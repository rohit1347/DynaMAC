# %%
from mac_simulator import *
from tdma_simulator import *
from mac_selection import *
from qlearning_optimized import *
from dynamac_switch_test import *
import matplotlib.pyplot as plt

# %% [markdown]
# # CSMA Plots

# %%
generate_xput_plots(montecarlo=10, num_n_end=20,
                    num_p=20, duration=20, num_n_delta=2)
# Out:
# tency=0.0s, PSR= 1.0, Ineligible packets: 203, Tx End Time: None
# Window xput: 2.2 packets/second, sent packets:22
# ---------------------------------------
# Mean latency across windows: 0.0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 18 packets
# Num. ineligible packets at simulation start: 185
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 185, Tx End Time: None
# Window xput: 1.8 packets/second, sent packets:18
# ---------------------------------------
# Mean latency across windows: 0.0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 19 packets
# Num. ineligible packets at simulation start: 166
# Tback:3.2
# Sim window stats - average latency=0.06315789473684189s, PSR= 1.0, Ineligible packets: 166, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.012765957446808465
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 22 packets
# Num. ineligible packets at simulation start: 144
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 144, Tx End Time: None
# Window xput: 2.2 packets/second, sent packets:22
# ---------------------------------------
# Mean latency across windows: 0.01034482758620686
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 20 packets
# Num. ineligible packets at simulation start: 124
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 124, Tx End Time: None
# Window xput: 2.0 packets/second, sent packets:20
# ---------------------------------------
# Mean latency across windows: 0.008823529411764675
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 20 packets
# Num. ineligible packets at simulation start: 104
# Tback:2.8
# Sim window stats - average latency=0.08999999999999986s, PSR= 1.0, Ineligible packets: 104, Tx End Time: None
# Window xput: 2.0 packets/second, sent packets:20
# ---------------------------------------
# Mean latency across windows: 0.019230769230769187
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 21 packets
# Num. ineligible packets at simulation start: 83
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 83, Tx End Time: None
# Window xput: 2.1 packets/second, sent packets:21
# ---------------------------------------
# Mean latency across windows: 0.01694915254237284
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 22 packets
# Num. ineligible packets at simulation start: 61
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 61, Tx End Time: None
# Window xput: 2.2 packets/second, sent packets:22
# ---------------------------------------
# Mean latency across windows: 0.015075376884422075
# Events size in gen:(4, 300)
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 18 packets
# Num. ineligible packets at simulation start: 282
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 282, Tx End Time: None
# Window xput: 1.8 packets/second, sent packets:18
# ---------------------------------------
# Mean latency across windows: 0.0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 18 packets
# Num. ineligible packets at simulation start: 264
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 264, Tx End Time: None
# Window xput: 1.8 packets/second, sent packets:18
# ---------------------------------------
# Mean latency across windows: 0.0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 22 packets
# Num. ineligible packets at simulation start: 242
# Tback:2.7
# Sim window stats - average latency=0.07727272727272724s, PSR= 1.0, Ineligible packets: 242, Tx End Time: None
# Window xput: 2.2 packets/second, sent packets:22
# ---------------------------------------
# Mean latency across windows: 0.029310344827586196
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 19 packets
# Num. ineligible packets at simulation start: 223
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 223, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.022077922077922068
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 20 packets
# Num. ineligible packets at simulation start: 203
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 203, Tx End Time: None
# Window xput: 2.0 packets/second, sent packets:20
# ---------------------------------------
# Mean latency across windows: 0.017525773195876282
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 19 packets
# Num. ineligible packets at simulation start: 184
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 184, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.014655172413793098
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 20 packets
# Num. ineligible packets at simulation start: 164
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 164, Tx End Time: None
# Window xput: 2.0 packets/second, sent packets:20
# ---------------------------------------
# Mean latency across windows: 0.012499999999999995
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 21 packets
# Num. ineligible packets at simulation start: 143
# Tback:2.8
# Sim window stats - average latency=0.08571428571428558s, PSR= 1.0, Ineligible packets: 143, Tx End Time: None
# Window xput: 2.1 packets/second, sent packets:21
# ---------------------------------------
# Mean latency across windows: 0.022292993630573226
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 20 packets
# Num. ineligible packets at simulation start: 123
# Tback:7.4
# Sim window stats - average latency=0.16999999999999957s, PSR= 1.0, Ineligible packets: 123, Tx End Time: None
# Window xput: 2.0 packets/second, sent packets:20
# ---------------------------------------
# Mean latency across windows: 0.03898305084745756
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 16 packets
# Num. ineligible packets at simulation start: 107
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 107, Tx End Time: None
# Window xput: 1.6 packets/second, sent packets:16
# ---------------------------------------
# Mean latency across windows: 0.0357512953367875
# Events size in gen:(4, 340)
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 18 packets
# Num. ineligible packets at simulation start: 322
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 322, Tx End Time: None
# Window xput: 1.8 packets/second, sent packets:18
# ---------------------------------------
# Mean latency across windows: 0.0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 20 packets
# Num. ineligible packets at simulation start: 302
# Tback:1.8
# Sim window stats - average latency=0.040000000000000036s, PSR= 1.0, Ineligible packets: 302, Tx End Time: None
# Window xput: 2.0 packets/second, sent packets:20
# ---------------------------------------
# Mean latency across windows: 0.02105263157894739
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 20 packets
# Num. ineligible packets at simulation start: 282
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 282, Tx End Time: None
# Window xput: 2.0 packets/second, sent packets:20
# ---------------------------------------
# Mean latency across windows: 0.013793103448275874
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 19 packets
# Num. ineligible packets at simulation start: 263
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 263, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.010389610389610398
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 21 packets
# Num. ineligible packets at simulation start: 242
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 242, Tx End Time: None
# Window xput: 2.1 packets/second, sent packets:21
# ---------------------------------------
# Mean latency across windows: 0.008163265306122457
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 21 packets
# Num. ineligible packets at simulation start: 221
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 221, Tx End Time: None
# Window xput: 2.1 packets/second, sent packets:21
# ---------------------------------------
# Mean latency across windows: 0.006722689075630258
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 19 packets
# Num. ineligible packets at simulation start: 202
# Tback:1.6
# Sim window stats - average latency=0.03157894736842113s, PSR= 1.0, Ineligible packets: 202, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.010144927536231899
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 18 packets
# Num. ineligible packets at simulation start: 184
# Tback:2.1
# Sim window stats - average latency=0.0611111111111108s, PSR= 1.0, Ineligible packets: 184, Tx End Time: None
# Window xput: 1.8 packets/second, sent packets:18
# ---------------------------------------
# Mean latency across windows: 0.016025641025641003
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 22 packets
# Num. ineligible packets at simulation start: 162
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 162, Tx End Time: None
# Window xput: 2.2 packets/second, sent packets:22
# ---------------------------------------
# Mean latency across windows: 0.0140449438202247
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 18 packets
# Num. ineligible packets at simulation start: 144
# Tback:2.7
# Sim window stats - average latency=0.09444444444444461s, PSR= 1.0, Ineligible packets: 144, Tx End Time: None
# Window xput: 1.8 packets/second, sent packets:18
# ---------------------------------------
# Mean latency across windows: 0.021428571428571425
# Events size in gen:(4, 380)
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 18 packets
# Num. ineligible packets at simulation start: 362
# Tback:5.5
# Sim window stats - average latency=0.19444444444444445s, PSR= 1.0, Ineligible packets: 362, Tx End Time: None
# Window xput: 1.8 packets/second, sent packets:18
# ---------------------------------------
# Mean latency across windows: 0.19444444444444445
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 20 packets
# Num. ineligible packets at simulation start: 342
# Tback:2.6
# Sim window stats - average latency=0.07999999999999999s, PSR= 1.0, Ineligible packets: 342, Tx End Time: None
# Window xput: 2.0 packets/second, sent packets:20
# ---------------------------------------
# Mean latency across windows: 0.13421052631578947
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 19 packets
# Num. ineligible packets at simulation start: 323
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 323, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.08947368421052632
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 22 packets
# Num. ineligible packets at simulation start: 301
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 301, Tx End Time: None
# Window xput: 2.2 packets/second, sent packets:22
# ---------------------------------------
# Mean latency across windows: 0.06455696202531645
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 18 packets
# Num. ineligible packets at simulation start: 283
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 283, Tx End Time: None
# Window xput: 1.8 packets/second, sent packets:18
# ---------------------------------------
# Mean latency across windows: 0.05257731958762886
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 20 packets
# Num. ineligible packets at simulation start: 264
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 0.95, Ineligible packets: 264, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.04396551724137931
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 21 packets
# Num. ineligible packets at simulation start: 243
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 243, Tx End Time: None
# Window xput: 2.1 packets/second, sent packets:21
# ---------------------------------------
# Mean latency across windows: 0.03722627737226277
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 19 packets
# Num. ineligible packets at simulation start: 224
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 224, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.03269230769230769
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 19 packets
# Num. ineligible packets at simulation start: 205
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 205, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.02914285714285714
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 21 packets
# Num. ineligible packets at simulation start: 184
# Tback:2.7
# Sim window stats - average latency=0.08095238095238108s, PSR= 1.0, Ineligible packets: 184, Tx End Time: None
# Window xput: 2.1 packets/second, sent packets:21
# ---------------------------------------
# Mean latency across windows: 0.03469387755102042
# Events size in gen:(4, 100)
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 18 packets
# Num. ineligible packets at simulation start: 82
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 82, Tx End Time: None
# Window xput: 1.8 packets/second, sent packets:18
# ---------------------------------------
# Mean latency across windows: 0.0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 19 packets
# Num. ineligible packets at simulation start: 63
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 63, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 19 packets
# Num. ineligible packets at simulation start: 44
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 44, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 22 packets
# Num. ineligible packets at simulation start: 22
# Tback:4.0
# Sim window stats - average latency=0.09090909090909075s, PSR= 1.0, Ineligible packets: 22, Tx End Time: None
# Window xput: 2.2 packets/second, sent packets:22
# ---------------------------------------
# Mean latency across windows: 0.025641025641025595
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 21 packets
# Num. ineligible packets at simulation start: 1
# Tback:2.1
# Sim window stats - average latency=0.05238095238095245s, PSR= 1.0, Ineligible packets: 1, Tx End Time: None
# Window xput: 2.1 packets/second, sent packets:21
# ---------------------------------------
# Mean latency across windows: 0.03131313131313129
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 1 packets
# Num. ineligible packets at simulation start: 0
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 0, Tx End Time: [51.88]
# Window xput: 0.1 packets/second, sent packets:1
# ---------------------------------------
# Mean latency across windows: 0.03099999999999998
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 0 packets
# Num. ineligible packets at simulation start: 0
# Tback:0
# Sim window stats - average latency=nans, PSR= nan, Ineligible packets: 0, Tx End Time: None
# Window xput: 0.0 packets/second, sent packets:0
# ---------------------------------------
# Mean latency across windows: 0.03099999999999998
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 0 packets
# Num. ineligible packets at simulation start: 0
# Tback:0
# Sim window stats - average latency=nans, PSR= nan, Ineligible packets: 0, Tx End Time: None
# Window xput: 0.0 packets/second, sent packets:0
# ---------------------------------------
# Mean latency across windows: 0.03099999999999998
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 0 packets
# Num. ineligible packets at simulation start: 0
# Tback:0
# Sim window stats - average latency=nans, PSR= nan, Ineligible packets: 0, Tx End Time: None
# Window xput: 0.0 packets/second, sent packets:0
# ---------------------------------------
# Mean latency across windows: 0.03099999999999998
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 0 packets
# Num. ineligible packets at simulation start: 0
# Tback:0
# Sim window stats - average latency=nans, PSR= nan, Ineligible packets: 0, Tx End Time: None
# Window xput: 0.0 packets/second, sent packets:0
# ---------------------------------------
# Mean latency across windows: 0.03099999999999998
# Events size in gen:(4, 140)
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 19 packets
# Num. ineligible packets at simulation start: 121
# Tback:2.2
# Sim window stats - average latency=0.06315789473684211s, PSR= 1.0, Ineligible packets: 121, Tx End Time: None
# Window xput: 1.9 packets/second, sent packets:19
# ---------------------------------------
# Mean latency across windows: 0.06315789473684211
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 17 packets
# Num. ineligible packets at simulation start: 104
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 104, Tx End Time: None
# Window xput: 1.7 packets/second, sent packets:17
# ---------------------------------------
# Mean latency across windows: 0.03333333333333333
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 21 packets
# Num. ineligible packets at simulation start: 83
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 83, Tx End Time: None
# Window xput: 2.1 packets/second, sent packets:21
# ---------------------------------------
# Mean latency across windows: 0.021052631578947368
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 18 packets
# Num. ineligible packets at simulation start: 65
# Tback:2.3
# Sim window stats - average latency=0.07222222222222206s, PSR= 1.0, Ineligible packets: 65, Tx End Time: None
# Window xput: 1.8 packets/second, sent packets:18
# ---------------------------------------
# Mean latency across windows: 0.0333333333333333
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 23 packets
# Num. ineligible packets at simulation start: 42
# Tback:0
# Sim window stats - average latency=0.0s, PSR= 1.0, Ineligible packets: 42, Tx End Time: None
# Window xput: 2.3 packets/second, sent packets:23
# ---------------------------------------
# Mean latency across windows: 0.025510204081632626
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 18 packets
# Num. ineligible packets at simulation start: 24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e86616334b6b> in <module>
#       1 generate_xput_plots(montecarlo=100, num_n_end=20,
# ----> 2                     num_p=20, duration=20, num_n_delta=2)
#
# c:\Users\rohit\Documents\DynaMAC\mac_selection.py in generate_xput_plots(num_p, num_n_start, num_n_delta, num_n_end, montecarlo, duration)
#     112         for count, num_n in enumerate(num_ns):
#     113             latency_window_array, xput_window_array = DynaMAC_switch_test(
# --> 114                 num_p=num_p, num_n=num_n, duration=100, reg=1)
#     115             latency, xput = np.mean(
#     116                 latency_window_array), np.mean(xput_window_array)
#
# c:\Users\rohit\Documents\DynaMAC\mac_selection.py in DynaMAC_switch_test(num_p, num_n, window_size, round, duration, reg, MAC_flag)
#      42             latency, xput, _, simEvents, latency_tracker, pre_packets = csma_simulator(
#      43                 num_nodes=num_n, num_packets=num_p, sim_start_time=window_start, duration=window_size,
# ---> 44                 simEvents=simEvents, latency_tracker=latency_tracker, previously_sent_packets=pre_packets)
#      45         else:
#      46             print(simEvents.shape[1])
#
# c:\Users\rohit\Documents\DynaMAC\mac_simulator.py in csma_simulator(num_nodes, num_packets, sim_start_time, duration, packet_time, pflag, simEvents, round, latency_tracker, previously_sent_packets)
#     122             # latency_tracker[1, curID] = curTime - lat_time
#     123             pkt_idx = np.argwhere(np.isclose(
# --> 124                 latency_tracker[0, :], curID).flatten())
#     125             # pkt_idx = latency_tracker[0, (np.isclose(
#     126             #     latency_tracker[0, :], curID).flatten())]
#
# KeyboardInterrupt:

# %% [markdown]
# # TDMA Plots

# %%
get_TDMA_plots(num_packets=20, frame_duration=20, start_time=0, packet_time=0.01, num_slots=20, num_sims=10)
# num_sims controls the montecarlo runs
# Out:
# ize in gen:(4, 380)
# 0
# no_of_packets_sent:204
# transmission_time:4.65
# throughput:43.87096774193548
# average_latency:0.35128947368421065
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:261
# transmission_time:4.75
# throughput:54.94736842105263
# average_latency:0.5331315789473685
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:268
# transmission_time:4.9
# throughput:54.69387755102041
# average_latency:0.5593157894736842
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:305
# transmission_time:4.45
# throughput:68.53932584269663
# average_latency:0.6511842105263158
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:285
# transmission_time:4.9
# throughput:58.16326530612245
# average_latency:0.5505000000000001
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:273
# transmission_time:4.95
# throughput:55.15151515151515
# average_latency:0.5338157894736844
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:263
# transmission_time:4.8
# throughput:54.79166666666667
# average_latency:0.5186315789473684
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:224
# transmission_time:4.8
# throughput:46.66666666666667
# average_latency:0.4910789473684211
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:224
# transmission_time:4.45
# throughput:50.33707865168539
# average_latency:0.4655263157894738
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:277
# transmission_time:4.45
# throughput:62.247191011235955
# average_latency:0.5655263157894738
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:314
# transmission_time:4.55
# throughput:69.01098901098901
# average_latency:0.6518947368421053
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:274
# transmission_time:4.75
# throughput:57.68421052631579
# average_latency:0.5296578947368422
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:265
# transmission_time:4.65
# throughput:56.98924731182795
# average_latency:0.5027894736842106
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:301
# transmission_time:4.8
# throughput:62.708333333333336
# average_latency:0.5770263157894738
# ------------------------------
# Events size in gen:(4, 380)
# 0
# no_of_packets_sent:254
# transmission_time:4.25
# throughput:59.76470588235294
# average_latency:0.5450263157894737
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:245
# transmission_time:5.0
# throughput:49.0
# average_latency:0.4935
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:235
# transmission_time:4.75
# throughput:49.473684210526315
# average_latency:0.486875
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:200
# transmission_time:4.8
# throughput:41.66666666666667
# average_latency:0.36712500000000003
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:280
# transmission_time:4.55
# throughput:61.53846153846154
# average_latency:0.5698750000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:205
# transmission_time:4.7
# throughput:43.61702127659574
# average_latency:0.389875
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:205
# transmission_time:4.45
# throughput:46.067415730337075
# average_latency:0.3975
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:260
# transmission_time:4.95
# throughput:52.525252525252526
# average_latency:0.5062500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:280
# transmission_time:4.75
# throughput:58.94736842105263
# average_latency:0.5876250000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:300
# transmission_time:4.85
# throughput:61.85567010309279
# average_latency:0.6422500000000002
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:180
# transmission_time:4.85
# throughput:37.11340206185567
# average_latency:0.319125
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:250
# transmission_time:5.0
# throughput:50.0
# average_latency:0.5117500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:230
# transmission_time:5.0
# throughput:46.0
# average_latency:0.4517500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:215
# transmission_time:5.0
# throughput:43.0
# average_latency:0.41887500000000005
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:285
# transmission_time:4.6
# throughput:61.95652173913044
# average_latency:0.5992500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:230
# transmission_time:4.45
# throughput:51.68539325842696
# average_latency:0.48200000000000004
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:275
# transmission_time:5.0
# throughput:55.0
# average_latency:0.5747500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:305
# transmission_time:4.7
# throughput:64.8936170212766
# average_latency:0.6475000000000002
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:225
# transmission_time:5.0
# throughput:45.0
# average_latency:0.46550000000000014
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:265
# transmission_time:4.4
# throughput:60.22727272727272
# average_latency:0.5382500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:285
# transmission_time:4.9
# throughput:58.16326530612245
# average_latency:0.5585000000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:250
# transmission_time:4.45
# throughput:56.17977528089887
# average_latency:0.5175000000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:250
# transmission_time:4.85
# throughput:51.54639175257732
# average_latency:0.522625
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:255
# transmission_time:4.95
# throughput:51.515151515151516
# average_latency:0.503625
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:255
# transmission_time:4.8
# throughput:53.125
# average_latency:0.51975
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:290
# transmission_time:4.45
# throughput:65.16853932584269
# average_latency:0.57725
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:250
# transmission_time:4.75
# throughput:52.63157894736842
# average_latency:0.4961250000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:195
# transmission_time:5.0
# throughput:39.0
# average_latency:0.34975
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:230
# transmission_time:4.55
# throughput:50.549450549450555
# average_latency:0.48275000000000007
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:265
# transmission_time:4.8
# throughput:55.208333333333336
# average_latency:0.5305000000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:230
# transmission_time:4.4
# throughput:52.272727272727266
# average_latency:0.48075
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:270
# transmission_time:4.95
# throughput:54.54545454545455
# average_latency:0.5186250000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:235
# transmission_time:4.6
# throughput:51.08695652173913
# average_latency:0.473125
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:270
# transmission_time:5.0
# throughput:54.0
# average_latency:0.5520000000000002
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:275
# transmission_time:4.45
# throughput:61.79775280898876
# average_latency:0.5411250000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:320
# transmission_time:4.5
# throughput:71.11111111111111
# average_latency:0.6818750000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:210
# transmission_time:4.7
# throughput:44.680851063829785
# average_latency:0.4307500000000002
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:270
# transmission_time:4.7
# throughput:57.4468085106383
# average_latency:0.5615000000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:285
# transmission_time:4.45
# throughput:64.04494382022472
# average_latency:0.5823750000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:250
# transmission_time:4.8
# throughput:52.083333333333336
# average_latency:0.49150000000000005
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:270
# transmission_time:5.0
# throughput:54.0
# average_latency:0.543875
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:260
# transmission_time:4.5
# throughput:57.77777777777778
# average_latency:0.51275
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:250
# transmission_time:4.45
# throughput:56.17977528089887
# average_latency:0.4995000000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:230
# transmission_time:4.6
# throughput:50.00000000000001
# average_latency:0.4286250000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:280
# transmission_time:4.9
# throughput:57.14285714285714
# average_latency:0.5558750000000002
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:220
# transmission_time:4.85
# throughput:45.36082474226804
# average_latency:0.4225000000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:260
# transmission_time:5.0
# throughput:52.0
# average_latency:0.503
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:245
# transmission_time:4.75
# throughput:51.578947368421055
# average_latency:0.4703750000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:190
# transmission_time:4.95
# throughput:38.38383838383838
# average_latency:0.4022500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:225
# transmission_time:4.95
# throughput:45.45454545454545
# average_latency:0.44037500000000007
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:255
# transmission_time:4.6
# throughput:55.434782608695656
# average_latency:0.51675
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:265
# transmission_time:4.75
# throughput:55.78947368421053
# average_latency:0.48174999999999996
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:235
# transmission_time:4.9
# throughput:47.95918367346938
# average_latency:0.43612500000000004
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:230
# transmission_time:4.75
# throughput:48.421052631578945
# average_latency:0.4643750000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:265
# transmission_time:4.95
# throughput:53.535353535353536
# average_latency:0.5146250000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:215
# transmission_time:4.95
# throughput:43.43434343434343
# average_latency:0.4318750000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:285
# transmission_time:4.6
# throughput:61.95652173913044
# average_latency:0.58725
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:240
# transmission_time:4.7
# throughput:51.06382978723404
# average_latency:0.4927500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:270
# transmission_time:4.5
# throughput:60.0
# average_latency:0.531875
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:245
# transmission_time:4.15
# throughput:59.03614457831325
# average_latency:0.5027500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:215
# transmission_time:4.75
# throughput:45.26315789473684
# average_latency:0.440625
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:275
# transmission_time:5.0
# throughput:55.0
# average_latency:0.5628750000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:240
# transmission_time:4.7
# throughput:51.06382978723404
# average_latency:0.481125
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:220
# transmission_time:4.75
# throughput:46.31578947368421
# average_latency:0.41587500000000005
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:260
# transmission_time:4.95
# throughput:52.525252525252526
# average_latency:0.509625
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:280
# transmission_time:4.1
# throughput:68.29268292682927
# average_latency:0.5868750000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:250
# transmission_time:5.0
# throughput:50.0
# average_latency:0.491375
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:215
# transmission_time:4.9
# throughput:43.87755102040816
# average_latency:0.4485
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:245
# transmission_time:4.15
# throughput:59.03614457831325
# average_latency:0.46462500000000007
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:265
# transmission_time:4.55
# throughput:58.24175824175824
# average_latency:0.5366250000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:220
# transmission_time:4.6
# throughput:47.82608695652174
# average_latency:0.4285
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:235
# transmission_time:4.65
# throughput:50.537634408602145
# average_latency:0.47050000000000014
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:265
# transmission_time:4.3
# throughput:61.627906976744185
# average_latency:0.555
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:300
# transmission_time:4.8
# throughput:62.5
# average_latency:0.6551250000000002
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:230
# transmission_time:4.7
# throughput:48.93617021276596
# average_latency:0.47424999999999995
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:230
# transmission_time:4.3
# throughput:53.48837209302326
# average_latency:0.45212500000000005
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:225
# transmission_time:4.45
# throughput:50.561797752808985
# average_latency:0.42450000000000004
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:240
# transmission_time:4.75
# throughput:50.526315789473685
# average_latency:0.4585000000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:225
# transmission_time:4.6
# throughput:48.913043478260875
# average_latency:0.4362500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:245
# transmission_time:4.2
# throughput:58.33333333333333
# average_latency:0.515375
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:315
# transmission_time:4.6
# throughput:68.47826086956522
# average_latency:0.6460000000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:250
# transmission_time:5.0
# throughput:50.0
# average_latency:0.5030000000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:245
# transmission_time:4.55
# throughput:53.84615384615385
# average_latency:0.45675
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:225
# transmission_time:4.65
# throughput:48.387096774193544
# average_latency:0.4493750000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:295
# transmission_time:4.5
# throughput:65.55555555555556
# average_latency:0.6108750000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:280
# transmission_time:4.8
# throughput:58.333333333333336
# average_latency:0.5745000000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:305
# transmission_time:4.7
# throughput:64.8936170212766
# average_latency:0.6256250000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:260
# transmission_time:4.95
# throughput:52.525252525252526
# average_latency:0.5472500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:250
# transmission_time:4.95
# throughput:50.505050505050505
# average_latency:0.50325
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:215
# transmission_time:5.0
# throughput:43.0
# average_latency:0.4221250000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:245
# transmission_time:4.9
# throughput:49.99999999999999
# average_latency:0.49562500000000015
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:235
# transmission_time:4.8
# throughput:48.958333333333336
# average_latency:0.46275000000000005
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:220
# transmission_time:4.55
# throughput:48.35164835164835
# average_latency:0.45612500000000006
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:245
# transmission_time:4.85
# throughput:50.51546391752578
# average_latency:0.5172500000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:235
# transmission_time:4.7
# throughput:50.0
# average_latency:0.452375
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:195
# transmission_time:4.85
# throughput:40.206185567010316
# average_latency:0.38000000000000006
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:260
# transmission_time:4.85
# throughput:53.608247422680414
# average_latency:0.5415000000000001
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:260
# transmission_time:4.9
# throughput:53.06122448979591
# average_latency:0.5175
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:250
# transmission_time:4.8
# throughput:52.083333333333336
# average_latency:0.5075000000000002
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:200
# transmission_time:4.85
# throughput:41.23711340206186
# average_latency:0.379125
# ------------------------------
# Events size in gen:(4, 400)
# 0
# no_of_packets_sent:245
# transmission_time:5.0
# throughput:49.0
# average_latency:0.47675000000000006
# ------------------------------
# [ 4.12839506  7.73929539 11.36784671 14.81486923 18.31613337 21.35567977
#  24.27431146 27.40722303 30.4647688  32.75935438 36.33061425 38.94355467
#  41.37176161 44.24912443 46.15190407 48.46951034 51.44458113 54.38157818
#  57.82884323 52.75647122]
# [ 0.13300412  0.57685588  1.05522656  2.76179518  3.25958511  5.23583465
#   6.86849045  9.06894519  9.17219695 12.36903497 15.29027163 15.22963386
#  18.17078368 18.36090447 33.6414516  38.89614175 32.65398854 43.76425971
#  46.10811446 48.22255308]
# [0.4772     0.490975   0.50459167 0.50928375 0.505835   0.5147525
#  0.50775857 0.52244937 0.52723778 0.539295   0.53273182 0.52576417
#  0.52878346 0.53051036 0.52222167 0.51869344 0.52761618 0.5339325
#  0.54182789 0.49894375]
# [0.01126682 0.00991701 0.00694981 0.00802222 0.00836449 0.00644821
#  0.0066388  0.00595304 0.00552747 0.00473662 0.00561728 0.00430884
#  0.00429713 0.00391014 0.00582358 0.00553303 0.00380901 0.0053363
#  0.00435492 0.00474599]

# %% [markdown]
# # DynaMAC Plots

# %%
DynaMAC_comparison(num_n=10, num_p_per_s=2, duration_low=20, duration_high=20, window_size=5, high_low_factor=5)
# Out:
# Events size in gen:(4, 200)
# Events size in gen:(4, 400)
# 40
# 0
# no_of_packets_sent:38
# transmission_time:4.1
# throughput:9.26829268292683
# average_latency:0.01643333333333333
# ------------------------------
# 1
# 5
# no_of_packets_sent:54
# transmission_time:4.6
# throughput:11.73913043478261
# average_latency:0.021992882562277584
# ------------------------------
# 1
# 10
# no_of_packets_sent:48
# transmission_time:4.6
# throughput:10.434782608695652
# average_latency:0.029842519685039374
# ------------------------------
# 1
# 15
# no_of_packets_sent:60
# transmission_time:4.100000000000001
# throughput:14.63414634146341
# average_latency:0.046326086956521746
# ------------------------------
# 1
# 20
# no_of_packets_sent:75
# transmission_time:4.600000000000001
# throughput:16.30434782608695
# average_latency:0.06924999999999985
# ------------------------------
# 1
# 25
# no_of_packets_sent:25
# transmission_time:2.3000000000000007
# throughput:10.869565217391301
# average_latency:0.03169230769230773
# ------------------------------
# 1
# 30
# no_of_packets_sent:65
# transmission_time:4.799999999999997
# throughput:13.541666666666675
# average_latency:0.08166666666666676
# ------------------------------
# 1
# 35
# no_of_packets_sent:30
# transmission_time:4.899999999999999
# throughput:6.122448979591838
# average_latency:0.03723404255319149
# ------------------------------
# 1
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 42 packets
# Num. ineligible packets at simulation start: 558
# Tback:4.1
# Sim window stats - average latency=0.09999999999999994s, PSR= 0.07142857142857142, Ineligible packets: 558, Tx End Time: None
# Window xput: 0.6 packets/second, sent packets:3
# ---------------------------------------
# Mean latency across windows: 0.09999999999999994
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 59 packets
# Num. ineligible packets at simulation start: 500
# Tback:68.7
# Sim window stats - average latency=0.4673913043478261s, PSR= 0.7796610169491526, Ineligible packets: 500, Tx End Time: None
# Window xput: 9.2 packets/second, sent packets:46
# ---------------------------------------
# Mean latency across windows: 0.4448979591836735
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 67 packets
# Num. ineligible packets at simulation start: 446
# Tback:68.7
# Sim window stats - average latency=0.6722222222222222s, PSR= 0.8059701492537313, Ineligible packets: 446, Tx End Time: None
# Window xput: 10.8 packets/second, sent packets:54
# ---------------------------------------
# Mean latency across windows: 0.5640776699029125
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 59 packets
# Num. ineligible packets at simulation start: 400
# Tback:62.699999999999996
# Sim window stats - average latency=0.8842105263157893s, PSR= 0.9661016949152542, Ineligible packets: 400, Tx End Time: None
# Window xput: 11.4 packets/second, sent packets:57
# ---------------------------------------
# Mean latency across windows: 0.678125
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 82 packets
# Num. ineligible packets at simulation start: 320
# Tback:237.7
# Sim window stats - average latency=1.191935483870968s, PSR= 0.7560975609756098, Ineligible packets: 320, Tx End Time: None
# Window xput: 12.4 packets/second, sent packets:62
# ---------------------------------------
# Mean latency across windows: 0.8216216216216216
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 40 packets
# Num. ineligible packets at simulation start: 300
# Latency>2
# Tback:62.29999999999999
# Sim window stats - average latency=2.2449999999999997s, PSR= 1.0, Ineligible packets: 300, Tx End Time: None
# Window xput: 8.0 packets/second, sent packets:40
# ---------------------------------------
# Mean latency across windows: 1.0389312977099234
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 70 packets
# Num. ineligible packets at simulation start: 230
# Tback:169.00000000000003
# Sim window stats - average latency=1.015686274509804s, PSR= 0.7285714285714285, Ineligible packets: 230, Tx End Time: None
# Window xput: 10.2 packets/second, sent packets:51
# ---------------------------------------
# Mean latency across windows: 1.035143769968051
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 49 packets
# Num. ineligible packets at simulation start: 200
# Tback:77.49999999999999
# Sim window stats - average latency=1.7024390243902434s, PSR= 0.8367346938775511, Ineligible packets: 200, Tx End Time: None
# Window xput: 8.2 packets/second, sent packets:41
# ---------------------------------------
# Mean latency across windows: 1.1124293785310733
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 42 packets
# Num. ineligible packets at simulation start: 558
# Tback:4.0
# Sim window stats - average latency=0.0s, PSR= 0.047619047619047616, Ineligible packets: 558, Tx End Time: None
# Window xput: 0.4 packets/second, sent packets:2
# ---------------------------------------
# Mean latency across windows: 0.0
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 60 packets
# Num. ineligible packets at simulation start: 500
# Tback:73.19999999999999
# Sim window stats - average latency=0.5260000000000001s, PSR= 0.8333333333333334, Ineligible packets: 500, Tx End Time: None
# Window xput: 10.0 packets/second, sent packets:50
# ---------------------------------------
# Mean latency across windows: 0.5057692307692309
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 64 packets
# Num. ineligible packets at simulation start: 446
# Tback:79.49999999999999
# Sim window stats - average latency=0.7563636363636367s, PSR= 0.859375, Ineligible packets: 446, Tx End Time: None
# Window xput: 11.0 packets/second, sent packets:55
# ---------------------------------------
# Mean latency across windows: 0.6345794392523365
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 55 packets
# Num. ineligible packets at simulation start: 400
# Tback:54.300000000000004
# Sim window stats - average latency=0.7773584905660379s, PSR= 0.9636363636363636, Ineligible packets: 400, Tx End Time: None
# Window xput: 10.6 packets/second, sent packets:53
# ---------------------------------------
# Mean latency across windows: 0.681875
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 82 packets
# Num. ineligible packets at simulation start: 320
# Tback:206.20000000000007
# Sim window stats - average latency=1.016923076923077s, PSR= 0.7926829268292683, Ineligible packets: 320, Tx End Time: None
# Window xput: 13.0 packets/second, sent packets:65
# ---------------------------------------
# Mean latency across windows: 0.7786666666666667
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 37 packets
# Num. ineligible packets at simulation start: 300
# Tback:51.0
# Sim window stats - average latency=1.7837837837837838s, PSR= 1.0, Ineligible packets: 300, Tx End Time: None
# Window xput: 7.4 packets/second, sent packets:37
# ---------------------------------------
# Mean latency across windows: 0.9206106870229008
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 70 packets
# Num. ineligible packets at simulation start: 230
# Tback:154.90000000000003
# Sim window stats - average latency=0.8846153846153848s, PSR= 0.7428571428571429, Ineligible packets: 230, Tx End Time: None
# Window xput: 10.4 packets/second, sent packets:52
# ---------------------------------------
# Mean latency across windows: 0.9146496815286626
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 48 packets
# Num. ineligible packets at simulation start: 200
# Tback:62.9
# Sim window stats - average latency=1.365s, PSR= 0.8333333333333334, Ineligible packets: 200, Tx End Time: None
# Window xput: 8.0 packets/second, sent packets:40
# ---------------------------------------
# Mean latency across windows: 0.965536723163842
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 42 packets
# Num. ineligible packets at simulation start: 558
# Tback:3.8
# Sim window stats - average latency=0.06666666666666672s, PSR= 0.07142857142857142, Ineligible packets: 558, Tx End Time: None
# Window xput: 0.6 packets/second, sent packets:3
# ---------------------------------------
# Mean latency across windows: 0.06666666666666672
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 59 packets
# Num. ineligible packets at simulation start: 500
# Tback:69.7
# Sim window stats - average latency=0.4725490196078432s, PSR= 0.864406779661017, Ineligible packets: 500, Tx End Time: None
# Window xput: 10.2 packets/second, sent packets:51
# ---------------------------------------
# Mean latency across windows: 0.44999999999999996
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 62 packets
# Num. ineligible packets at simulation start: 446
# Tback:60.60000000000001
# Sim window stats - average latency=0.5703703703703703s, PSR= 0.8709677419354839, Ineligible packets: 446, Tx End Time: None
# Window xput: 10.8 packets/second, sent packets:54
# ---------------------------------------
# Mean latency across windows: 0.5101851851851851
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 54 packets
# Num. ineligible packets at simulation start: 400
# Tback:55.40000000000001
# Sim window stats - average latency=0.6557692307692309s, PSR= 0.9629629629629629, Ineligible packets: 400, Tx End Time: None
# Window xput: 10.4 packets/second, sent packets:52
# ---------------------------------------
# Mean latency across windows: 0.5574999999999999
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 82 packets
# Num. ineligible packets at simulation start: 320
# Tback:208.60000000000008
# Sim window stats - average latency=1.0147540983606558s, PSR= 0.7439024390243902, Ineligible packets: 320, Tx End Time: None
# Window xput: 12.2 packets/second, sent packets:61
# ---------------------------------------
# Mean latency across windows: 0.6837104072398191
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 41 packets
# Num. ineligible packets at simulation start: 300
# Tback:65.30000000000001
# Sim window stats - average latency=1.982926829268293s, PSR= 1.0, Ineligible packets: 300, Tx End Time: None
# Window xput: 8.2 packets/second, sent packets:41
# ---------------------------------------
# Mean latency across windows: 0.8870229007633589
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 70 packets
# Num. ineligible packets at simulation start: 230
# Tback:156.50000000000003
# Sim window stats - average latency=0.9055555555555559s, PSR= 0.7714285714285715, Ineligible packets: 230, Tx End Time: None
# Window xput: 10.8 packets/second, sent packets:54
# ---------------------------------------
# Mean latency across windows: 0.8901898734177217
# 0
# Using given simEvents
# Dropped packets:0
# Num. eligible packets in window: 46 packets
# Num. ineligible packets at simulation start: 200
# Tback:60.60000000000001
# Sim window stats - average latency=1.2921052631578949s, PSR= 0.8260869565217391, Ineligible packets: 200, Tx End Time: None
# Window xput: 7.6 packets/second, sent packets:38
# ---------------------------------------
# Mean latency across windows: 0.9333333333333335
# 0
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
